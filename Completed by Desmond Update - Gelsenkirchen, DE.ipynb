# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
#excercise 1: Product List

Products = ["t-shirt", "mug", "hat", "book", "keychain", "boots", "slippers", "glasses", "toothbrush", "toachbrush holder", "mobile phone"]
Products.append("mobile phone")
print(Products[1:6])
# Out:
# ['mug', 'hat', 'book', 'keychain', 'boots']

# %%
#excercise 2: EmptyDict  

Inventory = {}

# %%
#excercise 3: User Input 
Products = {"t-shirt": 15, "mug": 5, " hat": 8, "book": 3, "keychain": 12, "boots": 7, "slippers": 10, "glasses": 6, "toothbrush": 9, "toachbrush holder": 4, "mobile phone": 11}
Inventory = {}
for product, quantity in Products.items():
    Inventory[product] = quantity

print("Inventory:", Inventory)
# Out:
# Inventory: {'t-shirt': 15, 'mug': 5, ' hat': 8, 'book': 3, 'keychain': 12, 'boots': 7, 'slippers': 10, 'glasses': 6, 'toothbrush': 9, 'toachbrush holder': 4, 'mobile phone': 11}

# %%
#excercise 4: Customer Orders

Purchases = []
customer_orders = set(Purchases)
# Out:
# set()

# %%
#excercise 5: Customer Orders
Purchases = ["mug", "hat", "keychain",]
customer_orders = set(Purchases)

# %%
#excercise 6:Print Customer Orders
Purchases = ["mug", "hat", "keychain",]
customer_orders = set(Purchases)
print(customer_orders)
# Out:
# {'mug', 'hat', 'keychain'}

# %%
#excercise 7:Calculate order statistics
total_Purchases_ordered = len(customer_orders)
percentage_ordered = (total_Purchases_ordered / len(Products)) * 100
order_status = (total_Purchases_ordered, round(percentage_ordered, 2))
print(order_status)
# Out:
# (3, 27.27)

# %%
#excercise 8:Calculate order statistics
print("\nPurchase Statistics:")
print(f"total_Purchases_ordered: {order_status[0]}")
print(f"Percentage of Purchases_ordered: {order_status[1]}%")
# Out:
# Purchase Statistics:
# total_Purchases_ordered: 3
# Percentage of Purchases_ordered: 27.27%

# %%
# 9. Update inventory (subtract 1 for each ordered product)

for product in customer_orders:
    if product in Inventory:
        Inventory[product] -= 1

# %%
# 10. Print updated inventory
for product in customer_orders:
    if product in Inventory:
        Inventory[product] -= 6
        print(f"Purchases ordered for {product}: {Inventory[product]}")
# Out:
# Purchases ordered for mug: -9
# Purchases ordered for keychain: -1

# %%
#excercise  : List

fruits = ["apple", "banana", "banana", "cherry", "mango", "pinaple", "guava", "pawpaw"]
fruits.append("melons")
print(fruits[1:6])
# Out:
# ['banana', 'banana', 'cherry', 'mango', 'pinaple']

# %%
#excercise : Dict  

students = {"name": "Desmond", "age": 25}
students["city"] = "Essen"
students["name"] = "Desmond Ugboaja"
students["age"] = 25
students["Hometown"] = "Lagos"
students["subjects"] = "Mathematics, Data Science, Python"
print(students)
# Out:
# {'name': 'Desmond Ugboaja', 'age': 25, 'city': 'Essen', 'Hometown': 'Lagos', 'subjects': 'Mathematics, Data Science, Python'}

# %%
#excercise : Set
duplicates = [1, 2, 2, 3, 4, 4, 5, 5, 5,  "james", "james", "john", "john"]
unique = set(duplicates)  
print(unique)
# Out:
# {1, 2, 3, 4, 5, 'james', 'john'}
